# %%
aa_array = ['Phe', 'Val', 'Asn', 'Gln', 'His', 'Leu', 'Cys', 'Gly', 'Ser']

print('Question 1.a', 'Output array')
print(aa_array, '\n')

print('Question 1.b', 'AA length')
aa_len = len(aa_array)
print('Amino Acid Length: ', aa_len, 'AA\n')

print('Question 1.c', 'Append His')
aa_array += ['His']
print(aa_array, '\n')1

print('Question 1.d', 'Retrieve AA by position')
while True:
    try:
        user_inp = int(input(f'Input number between 1 and {aa_len + 1}: '))
        user_inp -= 1
        print(aa_array[user_inp], '\n')
        break
    except Exception:
        pass
    print('Incorrect value given. Try again.')


print('Question 1.e', 'Switch AA by position')
while True:
    try:
        inp1 = int(input(f'Position 1: ')) - 1
        inp2 = int(input(f'Position 2: ')) - 1
        print('')
        print('Initial Array\n', aa_array)
        aa_array[inp1], aa_array[inp2] = aa_array[inp2], aa_array[inp1]
        print('Updated Array\n', aa_array)
        break
    except Exception:
        pass
    print('Incorrect value(s) given. Try again.')

print('\n')
print('Question 2')
q2_array = 'Trp Arg Liu Ilu Asp'.split(' ')
q2_len = len(q2_array)
while True:
    try:
        user_input = int(input(f'Input number between 1 and {q2_len + 1}: ')) - 1
        print(q2_array[user_input], '\n')
        break
    except Exception:
        print('Invalid input given. Try again')


print('')
print('Question 3  Array operations')
q3_array = list('CCGTAACGC')
print(q3_array, 'original Seq','\n')
print('Question 3.a  Add T')
q3_array += ['T']
print(q3_array, '\n')
print('Question 3.b  Pop element 1 and print')
print(q3_array.pop(0))
print(q3_array, '\n')
print('Question 3.c  Add T to beginning of the array')
q3_array = ['T'] + q3_array
print(q3_array, '\n')
print('Question 3.d  Output should be pretty.')
print('~ ^_^ ~')
# Out:
# Question 1.a Output array
# ['Phe', 'Val', 'Asn', 'Gln', 'His', 'Leu', 'Cys', 'Gly', 'Ser']
#
# Question 1.b AA length
# Amino Acid Length:  9 AA
#
# Question 1.c Append His
# ['Phe', 'Val', 'Asn', 'Gln', 'His', 'Leu', 'Cys', 'Gly', 'Ser', 'His']
#
# Question 1.d Retrieve AA by position
# Input number between 1 and 10:  3
# Asn
#
# Question 1.e Switch AA by position
# Position 1:  1
# Position 2:  3
# Initial Array
#  ['Phe', 'Val', 'Asn', 'Gln', 'His', 'Leu', 'Cys', 'Gly', 'Ser', 'His']
# Updated Array
#  ['Asn', 'Val', 'Phe', 'Gln', 'His', 'Leu', 'Cys', 'Gly', 'Ser', 'His']
#
# Question 2
# Input number between 1 and 6:  3
# Liu
#
#
# Question 3  Array operations
# ['C', 'C', 'G', 'T', 'A', 'A', 'C', 'G', 'C'] original Seq
#
# Question 3.a  Add T
# ['C', 'C', 'G', 'T', 'A', 'A', 'C', 'G', 'C', 'T']
#
# Question 3.b  Pop element 1 and print
# C
# ['C', 'G', 'T', 'A', 'A', 'C', 'G', 'C', 'T']
#
# Question 3.c  Add T to beginning of the array
# ...

# %%
import os
directory = 'week5'
os.mkdir(directory)
